# %% [markdown]
# Q1 Find the val%e of T(2) for the rec%rrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

# %% [markdown]
# Recurrence relation: T(n)=3T(n−1)+12n
#
# We need to find T(2), so we'll use the recurrence relation to express T(2) in terms of T(1) and
# T(1) in terms of T(0).
#
# T(2)=3T(1)+12×2
# Now, let's find
# T(1) using the same recurrence relation:
# T(1)=3T(0)+12×1
#
# Given that
# T(0)=5, we can substitute this value into the expression:
# T(1)=3×5+12×1
#
# Calculate
# T(1), and then substitute it back into the expression for
# T(2) to get the final result.
# T(2)=3×T(1)+12×2
#
# Calculate
# T(1) using the given recurrence relation:
# T(1)=3×T(0)+12×1
#
# Given that
# T(0)=5:
# T(1)=3×5+12×1=15+12=27
#
# Now that we have
# T(1), substitute it into the expression for
# T(2):
# T(2)=3×T(1)+12×2
#
# Substitute
# T(1)=27:
# T(2)=3×27+12×2=81+24=105
#
# So, the value of
# T(2) for the given recurrence relation
# T(n)=3T(n−1)+12n with the initial condition
# T(0)=5 is
# 105.

# %% [markdown]
# Q2. 2. Given a rec%rrence relation, solve it %sing the s%bstit%tion method:
# a. T(n) = T(n-1) + c
# b. T(n) = 2T(n/2) + n
# c. T(n) = 2T(n/2) + c
# d. T(n) = T(n/2) + c

# %% [markdown]
# Solutions
#
# Using substitution method for the solution:
#
# a. T(n)=T(n−1)+c
#
# Solution:
# expressing
# T(n) in terms of T(n−1) and continue until we reach the base case.
#
# T(n)=T(n−1)+c
# T(n−1)=T(n−2)+c
# T(n−2)=T(n−3)+c
# T(2)=T(1)+c
#
# T(1)=T(0)+c
#
# Now, substitute the expressions back into the original recurrence relation:
#
# T(n)=T(n−1)+c
# T(n)=(T(n−2)+c)+c
# T(n)=((T(n−3)+c)+c)+c
# ...
#
# T(n)=T(1)+c⋅(n−1)
# T(n)=T(0)+c⋅n
#
# Therefore, the solution for
#
# T(n)=T(n−1)+c is T(n)=T(0)+c⋅n.
#
#
# b. T(n)=2T(n/2)+n
#
# Solution:
# Let's use the substitution method for this recurrence relation:
# T(n)=2T(n/2)+n
#
# Assume
# T(k)=ck for some constant c and all
# k<n.
#
# Now, substitute this assumption into the recurrence relation:
# T(n)=2T(n/2)+n
#
# T(n)=2c(n/2)+n
# T(n)=cn+n
#
# T(n)=(c+1)n
#
# Therefore, the solution for T(n)=2T(n/2)+n is
#
# T(n)=(c+1)n.
#
# c.
# T(n)=2T(n/2)+c
#
# Solution:
# Using the same assumption as before,
# T(k)=ck:
#
# T(n)=2T(n/2)+c
# T(n)=2c(n/2)+c
#
# T(n)=cn+c
#
# Therefore, the solution for
# T(n)=2T(n/2)+c is
#
# T(n)=cn+c.
#
# d.
# T(n)=T(n/2)+c
#
# Solution:
# Using the same assumption as before,
# T(k)=ck:
#
# T(n)=T(n/2)+c
#
# T(n)=c(n/2)+c
# T(n)=cn/2+c
#
# Therefore, the solution for
# T(n)=T(n/2)+c is T(n)=cn/2+c.

# %% [markdown]
# 3. Given a rec%rrence relation, solve it %sing the rec%rsive tree approach:
# a. T(n) = 2T(n-1) +1
# b. T(n) = 2T(n/2) + n
#
# a. T(n)=2T(n−1)+1
#
# Solution:
# For this recurrence relation, let's visualize the recursive tree:
#
# scss
# Copy code
# T(n)
#    |
# T(n-1)
#    |
# T(n-2)
#    |
#  ...
#    |
# T(1)
#
# At each level, we have a cost of n because the cost is
#
# n at each node. The tree goes down to
# T(1). The total number of levels is
# log
#
# The total cost at each level is
# n, and there are n levels.
# T(n)=n+n+n+…+n=nlog2n
#
# Therefore, the solution for
#
# T(n)=2T(n/2)+n is
# T(n)=nlog2n
